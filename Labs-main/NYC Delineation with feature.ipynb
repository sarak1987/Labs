# %% [markdown]
# ## City district delineation using Graph Neural Networks
#
# ### Graph Neural Networks
#
#
# Graph Neural Networks (GNNs) are a class of deep learning methods designed to perform inference on data described by graphs. GNNs are neural networks that can be directly applied to graphs, and provide an easy way to do node-level, edge-level, and graph-level prediction tasks.
#
# Anything that is composed of linked entities can be represented as a graph. Graphs are excellent tools to visualize relations between people, objects, and concepts. With graphs becoming more pervasive and richer with information, and artificial neural networks becoming more popular and capable, GNNs have become a powerful tool for many important applications.
#
# <img src='GNN.png' width="600" height="600">
#
# Graph neural networks can be created like any other neural network, using fully connected layers, convolutional layers, pooling layers, etc. The type and number of layers depend on the type and complexity of the graph data and the desired output.
#
# The GNN receives the formatted graph data as input and produces a vector of numerical values that represent relevant information about nodes and their relations. This vector representation is called “graph embedding.”
#
# One very popular GNN architecture is the graph convolutional neural network (GCN), which uses convolution layers to create graph embeddings. (Kipf, T.N. and Welling, M., 2016. Semi-supervised classification with graph convolutional networks. https://arxiv.org/pdf/1609.02907.pdf)
#
# In the recent years, a lot of work has been done on the problem of generalizing neural networks to work on arbitrarily structured graphs - Bruna, J., Zaremba, W., Szlam, A. and LeCun, Y., 2013. Spectral networks and locally connected networks on graphs. https://arxiv.org/pdf/1312.6203.pdf%20http://arxiv.org/abs/1312.6203.pdf,  Henaff, M., Bruna, J. and LeCun, Y., 2015. Deep convolutional networks on graph-structured data. https://arxiv.org/abs/1506.05163 etc.
#
#
# Few applications for graph neural networks:
#
# - Node classification: One of the powerful applications of GNNs is adding new information to nodes or filling gaps where information is missing. For example, say you are running a social network and you have spotted a few bot accounts. Now you want to find out if there are other bot accounts in your network. You can train a GNN to classify other users in the social network as “bot” or “not bot” based on how close their graph embeddings are to those of the known bots.
#
# - Edge prediction: Another way to put GNNs to use is to find new edges that can add value to the graph. Going back to our social network, a GNN can find users (nodes) who are close to you in embedding space but who aren’t your friends yet (i.e., there isn’t an edge connecting you to each other). These users can then be introduced to you as friend suggestions.
#
# - Clustering: GNNs can glean new structural information from graphs. For example, in a social network where everyone is in one way or another related to others (through friends, or friends of friends, etc.), the GNN can find nodes that form clusters in the embedding space.
#
# A comprehensive tutorial on GNNs by Stanford is available on Youtube: https://www.youtube.com/watch?v=JAB_plj2rbA&list=PLoROMvodv4rPLKxIpqhjhPgdQy7imNkDn
#
# ### GNN for city delineation
#
# Here, we demonstrate an application for GNN for city borough delineation. The relationships among various entities such as interaction among people, intra-city mobility, social media interactions can be interpreted in terms of graphs with many features associated with nodes, edges.
#
# We will use the LEHD mobility network among zip codes in NYC and use it to learn the corresponding borough of zip codes (nodes) in the city.

# %%
# import packages

import networkx as nx
import pandas as pd
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
from torch.nn.parameter import Parameter
from torch.nn.modules.module import Module
torch.set_printoptions(sci_mode=False)
import time

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Data overview
#
# The LEHD mobility matrix contains the commute numbers between the home and work zip codes of the population...

# %%
data = pd.read_csv('data/zips_merged.csv', delimiter=',')
data = data.rename(columns={'total': 'weight', 'w_zip':'origin', 'h_zip':'destination'})
data = data[data.destination.isin(data.origin.unique())]
data.head()
# Out:
#    origin  destination  weight  initialFeat  true_label
# 0   11436        10009       1          4.0           4
# 1   11436        10011       1          4.0           4
# 2   11436        10013       1          4.0           4
# 3   11436        10019       1          4.0           4
# 4   11436        10021       1          4.0           4

# %%
# Add the population feature into the dataset

populationByAge = pd.read_csv('data/zicode_populationByAge.csv', delimiter=',')
populationByAge = populationByAge.iloc[:,0:2]
populationByAge.rename(columns={'ZIPCODE':'destination', 'Estimate!!Total!!Total population' : 'population' }, inplace=True)

# %%
# Add the house price feature into the dataset

housePrice = pd.read_csv('data/zipcode_housePrice.csv', delimiter=',')
weights = [5000,12500,17500,22500,27500,32500,37500,45000,55000,65000,75000,85000
                    ,95000,112500,137500,162500,187500,225000,275000,350000,450000,625000,875000
                        ,1250000,1750000,2000000]
for i in range(len(weights)):
    housePrice.iloc[i,2:] = housePrice.iloc[i,2:]*weights[i]
housePrice.iloc[:,1] [housePrice.iloc[:,1] == 0] = 1

tmp = (housePrice.iloc[:,2:] != 0 ).sum(axis=1)
tmp[tmp == 0] = 1
housePrice = pd.concat([housePrice.iloc[:,0],housePrice.iloc[:,2:].sum(axis=1) / tmp ], axis = 1 )
housePrice.rename(columns={'ZIPCODE':'destination', 0: 'house_price'}, inplace=True)

# %%
# Add the area size feature into the dataset

area = pd.read_csv('data/zips_area.csv', delimiter=',')
area = area.iloc[:,:2]
area.rename(columns={'ZIPCODE':'destination', 'AREA' : 'area'}, inplace=True)

# %%
# Add the income level feature into the dataset

income = pd.read_csv('data/zipcode_income.csv', delimiter=',')
income = income.iloc[:,:2]
income[income.isna()] = 0
income.rename(columns={'ZIPCODE':'destination', 'median_familyIncome(USD)' : 'income'}, inplace=True)

# %%
# Add the population jobs feature into the dataset

populationJobs = pd.read_csv('data/zipcode_population_Jobs.csv', delimiter=',')
populationJobs = populationJobs.iloc[:,:2]
populationJobs.rename(columns={'ZIPCODE':'destination', 'totalJobs' : 'jobs'}, inplace=True)

# %%
data = data.merge(populationByAge)
data = data.merge(housePrice)
data = data.merge(area)
data = data.merge(income)
data = data.merge(populationJobs)

# %%
# Normalize the features

data.iloc[:,5:]=(data.iloc[:,5:]-data.iloc[:,5:].min())/(data.iloc[:,5:].max()-data.iloc[:,5:].min())

# %%
data
# Out:
#        origin  destination  weight  initialFeat  true_label  population  \
# 0       11436        10009       1          4.0           4    0.300165
# 1       11213        10009      14          3.0           3    0.300165
# 2       11212        10009      27          3.0           3    0.300165
# 3       11225        10009      26          3.0           3    0.300165
# 4       11218        10009      60          3.0           3    0.300165
# ...       ...          ...     ...          ...         ...         ...
# 36407   11211        11371       7          1.0           3    0.000000
# 36408   11373        11371       3          4.0           4    0.000000
# 36409   10168        11371       1          1.0           1    0.000000
# 36410   10278        11371       1          1.0           1    0.000000
# 36411   10036        11371       5          1.0           1    0.000000
#
#        house_price      area    income      jobs
# 0         0.005332  0.032183  0.243977  0.042630
# 1         0.005332  0.032183  0.243977  0.042630
# 2         0.005332  0.032183  0.243977  0.042630
# 3         0.005332  0.032183  0.243977  0.042630
# 4         0.005332  0.032183  0.243977  0.042630
# ...            ...       ...       ...       ...
# 36407     0.000000  0.063146  0.000000  0.050874
# 36408     0.000000  0.063146  0.000000  0.050874
# 36409     0.000000  0.063146  0.000000  0.050874
# 36410     0.000000  0.063146  0.000000  0.050874
# 36411     0.000000  0.063146  0.000000  0.050874
#
# [36412 rows x 10 columns]

# %%
# set initial model config

cuda = torch.cuda.is_available()
weight_decay = 10e-4
epochs = 10001
seed = 165
hidden = 10
lr = 0.0001

# %%
np.random.seed(seed)
torch.manual_seed(seed)
if cuda:
    torch.cuda.manual_seed(seed)

# %% [markdown]
# We use a symmetric normalization for the propogating the layer, i.e. $$D^{−1/2}AD^{−1/2} $$

# %%
def normalize(adj):

    adj = torch.FloatTensor(adj)
    adj_id = torch.FloatTensor(torch.eye(adj.shape[1]))
    adj_id = adj_id.reshape((1, adj.shape[1], adj.shape[1]))
    adj_id = adj_id.repeat(adj.shape[0], 1, 1)
    adj = adj + adj_id
    rowsum = torch.FloatTensor(adj.sum(2))
    degree_mat_inv_sqrt = torch.diag_embed(torch.float_power(rowsum,-0.5), dim1=-2, dim2=-1).float()
    adj_norm = torch.bmm(torch.transpose(torch.bmm(adj,degree_mat_inv_sqrt),1,2),degree_mat_inv_sqrt)

    return adj_norm

# %% [markdown]
# The activation function for the GNN is the double ReLU which is linear between between 0 and 1

# %%
def doublerelu(x):
    return torch.clamp(x, 0, 1)

# %% [markdown]
# The Layer propogation rule of the GNN is : $$ H^{(l+1)} = f(H^{(l)}, A) = \sigma ( H^{(l)}W_1^{(l)} + \hat{D}^{-1/2}\hat{A}\hat{D}^{-1/2}H^{(l)}W_2^{(l)}) $$
#
# where H is the l'th neural network layer, A is the adjaceny matrix, D is the diagonal node degree matrix, W1 , W2 are learnable weight matrices initialised as W1 = 1, W2 = 0  and sigma is the activation function doublerelu.

# %%
class GNN1Layer(Module):

    def __init__(self, batch_size, in_features, out_features, first):
        super(GNN1Layer, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.batch_size = batch_size
        
        # Initialse W1 = 1, W2 = 0 as pytorch learnable weights (parameters) that have require_grad = True which is
        # required for calculating gradients while backpropogating using gradient descent
        weight1_eye = torch.FloatTensor(torch.eye(in_features, out_features))
        weight1_eye = weight1_eye.reshape((1, in_features, out_features))
        weight1_eye = weight1_eye.repeat(batch_size, 1, 1)
        self.weight1 = Parameter(weight1_eye)
        if not first:
            self.weight2 = Parameter(torch.zeros(batch_size, in_features, out_features))
        else:
            self.weight2 = Parameter(torch.empty(batch_size, in_features, out_features))
            nn.init.kaiming_normal_(self.weight2, mode='fan_out')

    def forward(self, input, adj):
        # first term H*W1
        v1 = torch.bmm(input, self.weight1)
        # second term adj_norm*H*W2
        v2 = torch.bmm(torch.bmm(adj, input), self.weight2)
        # adding the two terms
        output = v1 + v2
        return output

# %%
class GNN1(nn.Module):

    def __init__(self, batch_size, nfeat, ndim, hidden, first):
        super(GNN1, self).__init__()

        self.gc1 = GNN1Layer(batch_size, nfeat, ndim, first)

    def forward(self, x, adj, random_indices):
        f = torch.clone(x)
        # Applying activation function sigma (doublerelu) on the layer propogation
        x = doublerelu(self.gc1(x, adj))
        x = x/x.sum(axis=2).unsqueeze(2) #normalize st sum = 1
        
        # Only the train nodes are updated in backpropogation 
        f[0][random_indices, :x.shape[2]] = x[0][random_indices, :]
        
        return f[:,:,:x.shape[2]]

# %%
def train(adj,features,labels,random_indices,val_indices,val_features,first=False):
    
    # calculate symmetric normalisation for layer propogation
    adj_norm = normalize(adj)
    
    labels = labels - 1
    
    # Convert from numpy to torch tensors
    adj = torch.FloatTensor(adj)
    adj_norm = torch.FloatTensor(adj_norm)
    features = torch.FloatTensor(features)
    labels = torch.FloatTensor(labels)
    val_features = torch.FloatTensor(val_features)
    
    # initialise the mode
    model = GNN1(batch_size=adj.shape[0],
                nfeat=features.shape[-1],
                ndim=nb_label,
                hidden=hidden,
                first=first)
    
    # Transfer the weights to GPU for training
    if cuda:
        model.cuda()
        features = features.cuda()
        adj = adj.cuda()
        adj_norm = adj_norm.cuda()
        labels = labels.cuda()
        val_features = val_features.cuda()
    
    # Train model
    t_total = time.time()

    # Using adam optimizers for backpropogation
    optimizer = optim.Adam(model.parameters(),
                           lr=lr, weight_decay=weight_decay)
    
    # loss function criteria is cross entropy loss
    criterion = nn.CrossEntropyLoss()
    
    # Train for the no of epochs
    for epoch in range(epochs):

        t = time.time()
        model.train()
        
        # Pytorch accumulates gradient after every operation on tensors (defined by the model architecture)
        # with require_grad = True. With each new epoch, we need to reset this gradient to 0 to calculate gradient
        # for this epoch.
        optimizer.zero_grad()

        # get the output from forward propogation of our model
        output = model(features, adj_norm, random_indices)

        # Calculate Train accuracy
        train_output = output[:,random_indices,:]
        train_labels = labels[random_indices,:]
        train_accuracy = torch.sum(torch.argmax(train_output,axis=2)==train_labels.reshape(1,-1))/train_labels.shape[0]
        
        # Calculate Validation accuracy
        with torch.no_grad():
            val_output = model(val_features, adj_norm, val_indices)
            val_labels = labels[val_indices,:]
            val_accuracy = torch.sum(torch.argmax(val_output[0][val_indices, :],axis=1)==labels[val_indices, :].reshape(1,-1))/labels[val_indices, :].shape[0]
        
        # Calculate the loss between our models training output and true label
        loss = criterion(output[0],labels.reshape(-1).long())
        
        # Calculate the gradients 
        loss.backward(retain_graph=True)

        # Update the weights
        optimizer.step()

        # Print summary of training 
        if epoch == 0:
            best_loss = loss
            best_output = output
            best_acc = train_accuracy
            best_val_acc = val_accuracy
            best_val_output = val_output
        else:
            if loss < best_loss:
                best_loss = loss
                best_output = output
                best_acc = train_accuracy
                best_val_acc = val_accuracy
                best_val_output = val_output

        if epoch % 1000 == 0:
            print('Epoch: {:04d}'.format(epoch + 1),
                  'Train Accuracy: {:.4f}'.format(best_acc.item()),
                  'Validation Accuracy: {:.4f}'.format(best_val_acc.item()),
                  'Loss: {:.8f}'.format(best_loss.item()),
                  'time: {:.4f}s'.format(time.time() - t))
            
    print("Optimization Finished!")
    print("Total time elapsed: {:.4f}s".format(time.time() - t_total))
    
    return best_loss,best_output,best_val_output

# %%
def svdApprox(adj, dim, relu=False):
    adj = torch.FloatTensor(adj[0])
    U, S, Vh = torch.linalg.svd(adj)
    mu = torch.matmul(torch.matmul(U[:, :dim], torch.diag(S[:dim])), Vh[:dim, :])

    embedx = torch.matmul(U[:, :dim], torch.diag(torch.pow(S[:dim], 0.5)))
    embedy = torch.transpose(torch.matmul(torch.diag(torch.pow(S[:dim], 0.5)), Vh[:dim, :]), 0, 1)

    return embedx, embedy

# %%
# function for loading data, returns adjacency matrix, initial feature assignments and true labels

def load_data():

    G = nx.from_pandas_edgelist(data, 'origin', 'destination', 'weight',create_using=nx.DiGraph())
    adj_list = np.array([nx.adjacency_matrix(G).todense()], dtype=float)
    
    init_feat1 = np.array(data.groupby('origin')['population'].agg(['unique']))
    init_feat1 = np.array(list(map(lambda x: x[0][0], init_feat1))).reshape(-1, 1)
    init_feat2 = np.array(data.groupby('origin')['house_price'].agg(['unique']))
    init_feat2 = np.array(list(map(lambda x: x[0][0], init_feat2))).reshape(-1, 1)
    init_feat3 = np.array(data.groupby('origin')['area'].agg(['unique']))
    init_feat3 = np.array(list(map(lambda x: x[0][0], init_feat3))).reshape(-1, 1)
    init_feat4 = np.array(data.groupby('origin')['income'].agg(['unique']))
    init_feat4 = np.array(list(map(lambda x: x[0][0], init_feat4))).reshape(-1, 1)
    init_feat5 = np.array(data.groupby('origin')['jobs'].agg(['unique']))
    init_feat5 = np.array(list(map(lambda x: x[0][0], init_feat5))).reshape(-1, 1)
    
    init_feat = np.concatenate([init_feat1,init_feat2,init_feat3,init_feat4,init_feat5],axis=1)
    
    true_label = np.array(data.groupby('origin')['true_label'].agg(['unique']))
    
    true_label = np.array(list(map(lambda x: x[0][0], true_label))).reshape(-1, 1)
    return adj_list,init_feat,true_label

adj,feature,labels = load_data()

features = np.expand_dims(feature, axis=0)
val_features = np.copy(features)

# %%
init_feat = np.array(data.groupby('origin')['initialFeat'].agg(['unique']))
init_feat = np.array(list(map(lambda x: x[0][0], init_feat))).reshape(-1, 1)
init_feat = init_feat - 1
nb_label = int(max(init_feat)) + 1

# %%
# set Train %

train_percentage = .75
    
# Train set
number_of_rows = features[0].shape[0]
random_indices = np.random.choice(number_of_rows, size=int(train_percentage*number_of_rows), replace=False)
val_indices = np.setdiff1d(np.arange(adj.shape[1]),random_indices)

# Start Train
prev_loss, op, val_op = train(adj,features,labels, random_indices, val_indices, val_features, True)

# Keep training recurrently until the loss stops decreasing
loss, op, val_op = train(adj,op.cpu().detach().numpy(),labels, random_indices, val_indices, val_op.cpu().detach().numpy())
while loss < prev_loss :
    prev_loss = loss
    loss, op, val_op = train(adj,op.cpu().detach().numpy(),labels, random_indices, val_indices, val_op.cpu().detach().numpy())
# Out:
# Epoch: 0001 Train Accuracy: 0.2711 Validation Accuracy: 0.1429 Loss: 1.58509767 time: 0.0049s
# Epoch: 1001 Train Accuracy: 0.3735 Validation Accuracy: 0.3333 Loss: 1.56856894 time: 0.0008s
# Epoch: 2001 Train Accuracy: 0.3916 Validation Accuracy: 0.3571 Loss: 1.55656815 time: 0.0008s
# Epoch: 3001 Train Accuracy: 0.3313 Validation Accuracy: 0.2381 Loss: 1.50360680 time: 0.0008s
# Epoch: 4001 Train Accuracy: 0.3735 Validation Accuracy: 0.2143 Loss: 1.48460150 time: 0.0008s
# Epoch: 5001 Train Accuracy: 0.5060 Validation Accuracy: 0.4286 Loss: 1.47094047 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.5060 Validation Accuracy: 0.4286 Loss: 1.45996404 time: 0.0009s
# Epoch: 7001 Train Accuracy: 0.5120 Validation Accuracy: 0.4286 Loss: 1.44852006 time: 0.0013s
# Epoch: 8001 Train Accuracy: 0.5120 Validation Accuracy: 0.4286 Loss: 1.42669630 time: 0.0008s
# Epoch: 9001 Train Accuracy: 0.5120 Validation Accuracy: 0.4286 Loss: 1.42669630 time: 0.0010s
# Epoch: 10001 Train Accuracy: 0.5120 Validation Accuracy: 0.4286 Loss: 1.42669630 time: 0.0010s
# Optimization Finished!
# Total time elapsed: 9.6580s
# Epoch: 0001 Train Accuracy: 0.5120 Validation Accuracy: 0.4286 Loss: 1.42669630 time: 0.0010s
# Epoch: 1001 Train Accuracy: 0.5181 Validation Accuracy: 0.4286 Loss: 1.42156100 time: 0.0008s
# Epoch: 2001 Train Accuracy: 0.5120 Validation Accuracy: 0.4286 Loss: 1.41659141 time: 0.0011s
# Epoch: 3001 Train Accuracy: 0.5241 Validation Accuracy: 0.4524 Loss: 1.40181267 time: 0.0010s
# Epoch: 4001 Train Accuracy: 0.5241 Validation Accuracy: 0.4524 Loss: 1.40181267 time: 0.0011s
# Epoch: 5001 Train Accuracy: 0.5241 Validation Accuracy: 0.4524 Loss: 1.40181267 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.5241 Validation Accuracy: 0.4524 Loss: 1.40181267 time: 0.0009s
# Epoch: 7001 Train Accuracy: 0.5241 Validation Accuracy: 0.4524 Loss: 1.40181267 time: 0.0009s
# Epoch: 8001 Train Accuracy: 0.5241 Validation Accuracy: 0.4524 Loss: 1.40181267 time: 0.0014s
# Epoch: 9001 Train Accuracy: 0.5241 Validation Accuracy: 0.4524 Loss: 1.40181267 time: 0.0009s
# Epoch: 10001 Train Accuracy: 0.5241 Validation Accuracy: 0.4524 Loss: 1.40181267 time: 0.0011s
# Optimization Finished!
# Total time elapsed: 10.1007s
# Epoch: 0001 Train Accuracy: 0.5241 Validation Accuracy: 0.4524 Loss: 1.40181267 time: 0.0010s
# Epoch: 1001 Train Accuracy: 0.5482 Validation Accuracy: 0.4524 Loss: 1.39265871 time: 0.0008s
# Epoch: 2001 Train Accuracy: 0.5602 Validation Accuracy: 0.4524 Loss: 1.38542616 time: 0.0008s
# Epoch: 3001 Train Accuracy: 0.5602 Validation Accuracy: 0.4286 Loss: 1.38038194 time: 0.0009s
# Epoch: 4001 Train Accuracy: 0.5843 Validation Accuracy: 0.4286 Loss: 1.37260044 time: 0.0008s
# Epoch: 5001 Train Accuracy: 0.5904 Validation Accuracy: 0.4286 Loss: 1.36524153 time: 0.0010s
# Epoch: 6001 Train Accuracy: 0.5964 Validation Accuracy: 0.4286 Loss: 1.35573184 time: 0.0008s
# Epoch: 7001 Train Accuracy: 0.6145 Validation Accuracy: 0.4286 Loss: 1.34527278 time: 0.0009s
# Epoch: 8001 Train Accuracy: 0.6205 Validation Accuracy: 0.4286 Loss: 1.34025085 time: 0.0009s
# Epoch: 9001 Train Accuracy: 0.6205 Validation Accuracy: 0.4286 Loss: 1.34025085 time: 0.0009s
# Epoch: 10001 Train Accuracy: 0.6205 Validation Accuracy: 0.4286 Loss: 1.34025085 time: 0.0009s
# Optimization Finished!
# Total time elapsed: 10.5508s
# Epoch: 0001 Train Accuracy: 0.6205 Validation Accuracy: 0.4286 Loss: 1.34025085 time: 0.0010s
# Epoch: 1001 Train Accuracy: 0.6325 Validation Accuracy: 0.4286 Loss: 1.33641636 time: 0.0008s
# Epoch: 2001 Train Accuracy: 0.6265 Validation Accuracy: 0.4286 Loss: 1.33427119 time: 0.0008s
# Epoch: 3001 Train Accuracy: 0.6265 Validation Accuracy: 0.4286 Loss: 1.33223748 time: 0.0008s
# Epoch: 4001 Train Accuracy: 0.6386 Validation Accuracy: 0.4286 Loss: 1.32643330 time: 0.0008s
# Epoch: 5001 Train Accuracy: 0.6386 Validation Accuracy: 0.4286 Loss: 1.32643330 time: 0.0025s
# Epoch: 6001 Train Accuracy: 0.6386 Validation Accuracy: 0.4286 Loss: 1.32643330 time: 0.0008s
# Epoch: 7001 Train Accuracy: 0.6386 Validation Accuracy: 0.4286 Loss: 1.32643330 time: 0.0008s
# Epoch: 8001 Train Accuracy: 0.6386 Validation Accuracy: 0.4286 Loss: 1.32643330 time: 0.0009s
# Epoch: 9001 Train Accuracy: 0.6386 Validation Accuracy: 0.4286 Loss: 1.32643330 time: 0.0009s
# Epoch: 10001 Train Accuracy: 0.6386 Validation Accuracy: 0.4286 Loss: 1.32643330 time: 0.0009s
# Optimization Finished!
# Total time elapsed: 9.5294s
# Epoch: 0001 Train Accuracy: 0.6386 Validation Accuracy: 0.4286 Loss: 1.32643330 time: 0.0012s
# Epoch: 1001 Train Accuracy: 0.6325 Validation Accuracy: 0.4286 Loss: 1.32529473 time: 0.0014s
# Epoch: 2001 Train Accuracy: 0.6325 Validation Accuracy: 0.4286 Loss: 1.32412446 time: 0.0009s
# Epoch: 3001 Train Accuracy: 0.6325 Validation Accuracy: 0.4286 Loss: 1.32269561 time: 0.0008s
# Epoch: 4001 Train Accuracy: 0.6446 Validation Accuracy: 0.4286 Loss: 1.32078362 time: 0.0008s
# Epoch: 5001 Train Accuracy: 0.6386 Validation Accuracy: 0.4286 Loss: 1.31803596 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.6386 Validation Accuracy: 0.4286 Loss: 1.31610358 time: 0.0008s
# Epoch: 7001 Train Accuracy: 0.6386 Validation Accuracy: 0.4286 Loss: 1.31442630 time: 0.0008s
# Epoch: 8001 Train Accuracy: 0.6386 Validation Accuracy: 0.4286 Loss: 1.31442630 time: 0.0008s
# Epoch: 9001 Train Accuracy: 0.6386 Validation Accuracy: 0.4286 Loss: 1.31442630 time: 0.0015s
# Epoch: 10001 Train Accuracy: 0.6386 Validation Accuracy: 0.4286 Loss: 1.31442630 time: 0.0010s
# Optimization Finished!
# Total time elapsed: 9.5715s
# Epoch: 0001 Train Accuracy: 0.6386 Validation Accuracy: 0.4286 Loss: 1.31442630 time: 0.0015s
# Epoch: 1001 Train Accuracy: 0.6386 Validation Accuracy: 0.4286 Loss: 1.31302762 time: 0.0014s
# Epoch: 2001 Train Accuracy: 0.6386 Validation Accuracy: 0.4286 Loss: 1.31142378 time: 0.0009s
# Epoch: 3001 Train Accuracy: 0.6506 Validation Accuracy: 0.4286 Loss: 1.30998373 time: 0.0010s
# Epoch: 4001 Train Accuracy: 0.6506 Validation Accuracy: 0.4286 Loss: 1.30827475 time: 0.0008s
# Epoch: 5001 Train Accuracy: 0.6566 Validation Accuracy: 0.4286 Loss: 1.30614865 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.6687 Validation Accuracy: 0.4286 Loss: 1.29728317 time: 0.0008s
# Epoch: 7001 Train Accuracy: 0.6627 Validation Accuracy: 0.4286 Loss: 1.29540074 time: 0.0008s
# Epoch: 8001 Train Accuracy: 0.6627 Validation Accuracy: 0.4286 Loss: 1.29540074 time: 0.0008s
# Epoch: 9001 Train Accuracy: 0.6627 Validation Accuracy: 0.4286 Loss: 1.29540074 time: 0.0008s
# Epoch: 10001 Train Accuracy: 0.6627 Validation Accuracy: 0.4286 Loss: 1.29540074 time: 0.0009s
# Optimization Finished!
# Total time elapsed: 10.6267s
# Epoch: 0001 Train Accuracy: 0.6627 Validation Accuracy: 0.4286 Loss: 1.29540074 time: 0.0010s
# Epoch: 1001 Train Accuracy: 0.6687 Validation Accuracy: 0.4286 Loss: 1.29378641 time: 0.0008s
# Epoch: 2001 Train Accuracy: 0.6747 Validation Accuracy: 0.4286 Loss: 1.29185438 time: 0.0011s
# Epoch: 3001 Train Accuracy: 0.6867 Validation Accuracy: 0.4286 Loss: 1.28999019 time: 0.0008s
# Epoch: 4001 Train Accuracy: 0.6928 Validation Accuracy: 0.4286 Loss: 1.28657508 time: 0.0008s
# Epoch: 5001 Train Accuracy: 0.6867 Validation Accuracy: 0.4286 Loss: 1.28364265 time: 0.0009s
# Epoch: 6001 Train Accuracy: 0.6988 Validation Accuracy: 0.4286 Loss: 1.27960443 time: 0.0008s
# Epoch: 7001 Train Accuracy: 0.6988 Validation Accuracy: 0.4286 Loss: 1.27922106 time: 0.0011s
# Epoch: 8001 Train Accuracy: 0.6988 Validation Accuracy: 0.4286 Loss: 1.27922106 time: 0.0016s
# Epoch: 9001 Train Accuracy: 0.6988 Validation Accuracy: 0.4286 Loss: 1.27922106 time: 0.0015s
# Epoch: 10001 Train Accuracy: 0.6988 Validation Accuracy: 0.4286 Loss: 1.27922106 time: 0.0008s
# Optimization Finished!
# Total time elapsed: 10.8927s
# Epoch: 0001 Train Accuracy: 0.6988 Validation Accuracy: 0.4286 Loss: 1.27922106 time: 0.0009s
# Epoch: 1001 Train Accuracy: 0.6928 Validation Accuracy: 0.4286 Loss: 1.27663946 time: 0.0009s
# Epoch: 2001 Train Accuracy: 0.6928 Validation Accuracy: 0.4286 Loss: 1.27425826 time: 0.0008s
# Epoch: 3001 Train Accuracy: 0.6928 Validation Accuracy: 0.4286 Loss: 1.27245128 time: 0.0008s
# Epoch: 4001 Train Accuracy: 0.6988 Validation Accuracy: 0.4286 Loss: 1.26984215 time: 0.0009s
# Epoch: 5001 Train Accuracy: 0.7048 Validation Accuracy: 0.4286 Loss: 1.26591420 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.7048 Validation Accuracy: 0.4286 Loss: 1.26591420 time: 0.0008s
# Epoch: 7001 Train Accuracy: 0.7048 Validation Accuracy: 0.4286 Loss: 1.26591420 time: 0.0008s
# Epoch: 8001 Train Accuracy: 0.7048 Validation Accuracy: 0.4286 Loss: 1.26591420 time: 0.0011s
# Epoch: 9001 Train Accuracy: 0.7048 Validation Accuracy: 0.4286 Loss: 1.26591420 time: 0.0014s
# Epoch: 10001 Train Accuracy: 0.7048 Validation Accuracy: 0.4286 Loss: 1.26591420 time: 0.0008s
# Optimization Finished!
# Total time elapsed: 9.1509s
# Epoch: 0001 Train Accuracy: 0.7048 Validation Accuracy: 0.4286 Loss: 1.26591420 time: 0.0023s
# Epoch: 1001 Train Accuracy: 0.7108 Validation Accuracy: 0.4286 Loss: 1.26429045 time: 0.0009s
# Epoch: 2001 Train Accuracy: 0.7229 Validation Accuracy: 0.4286 Loss: 1.26053286 time: 0.0008s
# Epoch: 3001 Train Accuracy: 0.7229 Validation Accuracy: 0.4286 Loss: 1.25575042 time: 0.0010s
# Epoch: 4001 Train Accuracy: 0.7229 Validation Accuracy: 0.4286 Loss: 1.25516534 time: 0.0012s
# Epoch: 5001 Train Accuracy: 0.7229 Validation Accuracy: 0.4286 Loss: 1.25440192 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.7289 Validation Accuracy: 0.4286 Loss: 1.25028622 time: 0.0015s
# Epoch: 7001 Train Accuracy: 0.7349 Validation Accuracy: 0.4286 Loss: 1.24766779 time: 0.0011s
# Epoch: 8001 Train Accuracy: 0.7349 Validation Accuracy: 0.4286 Loss: 1.24712729 time: 0.0008s
# Epoch: 9001 Train Accuracy: 0.7349 Validation Accuracy: 0.4286 Loss: 1.24581730 time: 0.0009s
# Epoch: 10001 Train Accuracy: 0.7349 Validation Accuracy: 0.4286 Loss: 1.24511707 time: 0.0009s
# Optimization Finished!
# Total time elapsed: 14.3625s
# Epoch: 0001 Train Accuracy: 0.7349 Validation Accuracy: 0.4286 Loss: 1.24511707 time: 0.0010s
# Epoch: 1001 Train Accuracy: 0.7349 Validation Accuracy: 0.4286 Loss: 1.24476993 time: 0.0008s
# Epoch: 2001 Train Accuracy: 0.7349 Validation Accuracy: 0.4286 Loss: 1.24446976 time: 0.0009s
# Epoch: 3001 Train Accuracy: 0.7410 Validation Accuracy: 0.4286 Loss: 1.24415660 time: 0.0009s
# Epoch: 4001 Train Accuracy: 0.7349 Validation Accuracy: 0.4286 Loss: 1.24379182 time: 0.0008s
# Epoch: 5001 Train Accuracy: 0.7410 Validation Accuracy: 0.4286 Loss: 1.24333334 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.7410 Validation Accuracy: 0.4286 Loss: 1.24281454 time: 0.0009s
# Epoch: 7001 Train Accuracy: 0.7410 Validation Accuracy: 0.4286 Loss: 1.24213278 time: 0.0009s
# Epoch: 8001 Train Accuracy: 0.7410 Validation Accuracy: 0.4286 Loss: 1.24117446 time: 0.0009s
# Epoch: 9001 Train Accuracy: 0.7410 Validation Accuracy: 0.4286 Loss: 1.24117446 time: 0.0012s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23943269 time: 0.0011s
# Optimization Finished!
# Total time elapsed: 10.8381s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23943269 time: 0.0009s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23943019 time: 0.0008s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23942399 time: 0.0012s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23941410 time: 0.0008s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23939979 time: 0.0008s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23938239 time: 0.0009s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23936248 time: 0.0019s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23934054 time: 0.0010s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23931682 time: 0.0017s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23928499 time: 0.0008s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23912418 time: 0.0008s
# Optimization Finished!
# Total time elapsed: 10.2774s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23912418 time: 0.0009s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23912215 time: 0.0009s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23911834 time: 0.0008s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23911333 time: 0.0008s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23910689 time: 0.0008s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23909867 time: 0.0009s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23908746 time: 0.0008s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23906887 time: 0.0008s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23903847 time: 0.0009s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23898399 time: 0.0010s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23883939 time: 0.0019s
# Optimization Finished!
# Total time elapsed: 11.3013s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23883939 time: 0.0018s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23883832 time: 0.0012s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23883653 time: 0.0008s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23883414 time: 0.0009s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23883033 time: 0.0008s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23882484 time: 0.0009s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23881745 time: 0.0008s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23880661 time: 0.0014s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23878658 time: 0.0009s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23873603 time: 0.0009s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23863208 time: 0.0009s
# Optimization Finished!
# Total time elapsed: 10.9230s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23863208 time: 0.0011s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23863006 time: 0.0013s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23862779 time: 0.0009s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23862469 time: 0.0009s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23862123 time: 0.0012s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23861670 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23860979 time: 0.0008s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23859954 time: 0.0012s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23858237 time: 0.0009s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23854423 time: 0.0009s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23849094 time: 0.0009s
# Optimization Finished!
# Total time elapsed: 12.9844s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23849094 time: 0.0030s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23848891 time: 0.0009s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23848593 time: 0.0008s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23848212 time: 0.0010s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23847759 time: 0.0008s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23847198 time: 0.0015s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23846495 time: 0.0009s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23845410 time: 0.0012s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23843646 time: 0.0008s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23838747 time: 0.0009s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23835611 time: 0.0008s
# Optimization Finished!
# Total time elapsed: 12.1346s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23835611 time: 0.0012s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23835325 time: 0.0008s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23834944 time: 0.0008s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23834419 time: 0.0009s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23833787 time: 0.0009s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23833025 time: 0.0009s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23832011 time: 0.0009s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23830676 time: 0.0008s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23828387 time: 0.0009s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23821652 time: 0.0008s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23821270 time: 0.0008s
# Optimization Finished!
# Total time elapsed: 9.4510s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23821270 time: 0.0010s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23820996 time: 0.0008s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23820484 time: 0.0008s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23819780 time: 0.0008s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23818886 time: 0.0009s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23817754 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23816288 time: 0.0009s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23815334 time: 0.0008s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23814571 time: 0.0009s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23813570 time: 0.0009s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23812020 time: 0.0008s
# Optimization Finished!
# Total time elapsed: 8.8514s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23812020 time: 0.0010s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23811913 time: 0.0011s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23811865 time: 0.0008s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23811829 time: 0.0008s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23811746 time: 0.0008s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23811650 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23811519 time: 0.0008s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23811316 time: 0.0008s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23810983 time: 0.0009s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23810530 time: 0.0008s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23809505 time: 0.0008s
# Optimization Finished!
# Total time elapsed: 8.5684s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23809505 time: 0.0010s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23809445 time: 0.0008s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23809421 time: 0.0008s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23809385 time: 0.0008s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23809326 time: 0.0009s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23809254 time: 0.0009s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23809171 time: 0.0009s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23809040 time: 0.0009s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23808837 time: 0.0008s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23808408 time: 0.0008s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23807633 time: 0.0008s
# Optimization Finished!
# Total time elapsed: 8.5973s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23807633 time: 0.0010s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23807549 time: 0.0008s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23807526 time: 0.0009s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23807478 time: 0.0008s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23807442 time: 0.0009s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23807383 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23807275 time: 0.0008s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23807144 time: 0.0008s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23806930 time: 0.0008s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23806572 time: 0.0008s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23805785 time: 0.0009s
# Optimization Finished!
# Total time elapsed: 8.5324s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23805785 time: 0.0012s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23805749 time: 0.0008s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23805690 time: 0.0008s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23805630 time: 0.0008s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23805547 time: 0.0008s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23805451 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23805320 time: 0.0008s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23805106 time: 0.0008s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23804796 time: 0.0008s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23804259 time: 0.0008s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23802948 time: 0.0008s
# Optimization Finished!
# Total time elapsed: 8.5333s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23802948 time: 0.0010s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23802865 time: 0.0008s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23802817 time: 0.0008s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23802757 time: 0.0015s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23802674 time: 0.0008s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23802578 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23802459 time: 0.0008s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23802257 time: 0.0008s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23801911 time: 0.0008s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23801398 time: 0.0008s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23800087 time: 0.0011s
# Optimization Finished!
# Total time elapsed: 8.7116s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23800087 time: 0.0010s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23800075 time: 0.0008s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23800015 time: 0.0008s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23799968 time: 0.0010s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23799896 time: 0.0008s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23799813 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23799694 time: 0.0008s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23799503 time: 0.0009s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23799181 time: 0.0008s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23798645 time: 0.0009s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23797429 time: 0.0009s
# Optimization Finished!
# Total time elapsed: 8.5248s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23797429 time: 0.0010s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23797369 time: 0.0008s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23797309 time: 0.0009s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23797274 time: 0.0008s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23797214 time: 0.0009s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23797119 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23796988 time: 0.0008s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23796821 time: 0.0008s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23796523 time: 0.0008s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23795974 time: 0.0008s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23794723 time: 0.0008s
# Optimization Finished!
# Total time elapsed: 8.7047s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23794723 time: 0.0010s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23794675 time: 0.0011s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23794627 time: 0.0010s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23794568 time: 0.0008s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23794484 time: 0.0008s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23794413 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23794281 time: 0.0009s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23794067 time: 0.0008s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23793721 time: 0.0008s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23792911 time: 0.0009s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23788691 time: 0.0009s
# Optimization Finished!
# Total time elapsed: 8.5837s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23788691 time: 0.0009s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23788631 time: 0.0008s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23788559 time: 0.0008s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23788440 time: 0.0008s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23788249 time: 0.0008s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23788011 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23787570 time: 0.0008s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23786807 time: 0.0008s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23784971 time: 0.0009s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4286 Loss: 1.23779571 time: 0.0009s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23756647 time: 0.0008s
# Optimization Finished!
# Total time elapsed: 8.5272s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23756647 time: 0.0010s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23756206 time: 0.0008s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23755479 time: 0.0008s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23754489 time: 0.0009s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23753142 time: 0.0008s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23751271 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.7410 Validation Accuracy: 0.4048 Loss: 1.23748374 time: 0.0008s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23737550 time: 0.0008s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23734093 time: 0.0009s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23733306 time: 0.0009s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23732352 time: 0.0009s
# Optimization Finished!
# Total time elapsed: 8.5899s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23732352 time: 0.0012s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23732209 time: 0.0008s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23732126 time: 0.0008s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23731971 time: 0.0009s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23731720 time: 0.0008s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23731411 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23730993 time: 0.0008s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23730469 time: 0.0008s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23729789 time: 0.0008s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23728859 time: 0.0010s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23727429 time: 0.0008s
# Optimization Finished!
# Total time elapsed: 8.5261s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23727429 time: 0.0010s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23727357 time: 0.0009s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23727345 time: 0.0008s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23727298 time: 0.0009s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23727238 time: 0.0009s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23727155 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23727036 time: 0.0009s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23726892 time: 0.0009s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23726702 time: 0.0008s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23726320 time: 0.0010s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23725712 time: 0.0009s
# Optimization Finished!
# Total time elapsed: 8.5559s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23725712 time: 0.0010s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23725700 time: 0.0008s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23725688 time: 0.0009s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23725653 time: 0.0008s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23725617 time: 0.0008s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23725569 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23725486 time: 0.0008s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23725367 time: 0.0008s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23725212 time: 0.0009s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23724949 time: 0.0008s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23724496 time: 0.0010s
# Optimization Finished!
# Total time elapsed: 8.6990s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23724496 time: 0.0009s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23724484 time: 0.0010s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23724449 time: 0.0008s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23724437 time: 0.0008s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23724413 time: 0.0010s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23724365 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23724294 time: 0.0008s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23724222 time: 0.0008s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23724103 time: 0.0008s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23723865 time: 0.0009s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23723495 time: 0.0009s
# Optimization Finished!
# Total time elapsed: 8.5906s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23723495 time: 0.0011s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23723412 time: 0.0011s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23723400 time: 0.0008s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23723388 time: 0.0009s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23723352 time: 0.0008s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23723304 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23723269 time: 0.0008s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23723173 time: 0.0008s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23723090 time: 0.0011s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23722911 time: 0.0008s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23722517 time: 0.0010s
# Optimization Finished!
# Total time elapsed: 8.6983s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23722517 time: 0.0010s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23722517 time: 0.0009s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23722506 time: 0.0009s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23722482 time: 0.0008s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23722458 time: 0.0008s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23722434 time: 0.0010s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23722386 time: 0.0008s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23722327 time: 0.0009s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23722219 time: 0.0008s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23722076 time: 0.0009s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23721695 time: 0.0008s
# Optimization Finished!
# Total time elapsed: 8.5900s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23721695 time: 0.0010s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23721683 time: 0.0009s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23721671 time: 0.0009s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23721671 time: 0.0009s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23721635 time: 0.0009s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23721588 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23721564 time: 0.0008s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23721516 time: 0.0010s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23721421 time: 0.0008s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23721313 time: 0.0008s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23721004 time: 0.0008s
# Optimization Finished!
# Total time elapsed: 8.5965s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23721004 time: 0.0010s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23720980 time: 0.0008s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23720980 time: 0.0009s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23720956 time: 0.0009s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23720944 time: 0.0009s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23720920 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23720884 time: 0.0008s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23720813 time: 0.0008s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23720753 time: 0.0008s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23720670 time: 0.0009s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23720431 time: 0.0008s
# Optimization Finished!
# Total time elapsed: 8.4775s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23720431 time: 0.0010s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23720431 time: 0.0008s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23720419 time: 0.0008s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23720407 time: 0.0008s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23720384 time: 0.0008s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23720372 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23720348 time: 0.0008s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23720288 time: 0.0008s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23720229 time: 0.0009s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23720109 time: 0.0008s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23719966 time: 0.0009s
# Optimization Finished!
# Total time elapsed: 8.5829s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23719966 time: 0.0010s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23719966 time: 0.0008s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23719966 time: 0.0008s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23719954 time: 0.0008s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23719954 time: 0.0008s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23719907 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23719895 time: 0.0008s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23719847 time: 0.0008s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23719788 time: 0.0009s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23719680 time: 0.0011s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23719525 time: 0.0008s
# Optimization Finished!
# Total time elapsed: 8.5567s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23719525 time: 0.0012s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23719430 time: 0.0008s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23719430 time: 0.0009s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23719418 time: 0.0009s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23719406 time: 0.0009s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23719394 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23719382 time: 0.0008s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23719335 time: 0.0008s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23719287 time: 0.0008s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23719168 time: 0.0009s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23718965 time: 0.0008s
# Optimization Finished!
# Total time elapsed: 8.5954s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23718965 time: 0.0011s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23718953 time: 0.0008s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23718941 time: 0.0008s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23718917 time: 0.0009s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23718917 time: 0.0008s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23718894 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23718894 time: 0.0008s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23718858 time: 0.0008s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23718810 time: 0.0008s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23718691 time: 0.0009s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23718560 time: 0.0009s
# Optimization Finished!
# Total time elapsed: 8.5802s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23718560 time: 0.0010s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23718560 time: 0.0008s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23718560 time: 0.0008s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23718560 time: 0.0008s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23718536 time: 0.0008s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23718524 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23718512 time: 0.0008s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23718500 time: 0.0008s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23718441 time: 0.0010s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23718381 time: 0.0008s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23718202 time: 0.0008s
# Optimization Finished!
# Total time elapsed: 8.5590s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23718202 time: 0.0010s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23718190 time: 0.0008s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23718190 time: 0.0008s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23718190 time: 0.0009s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23718154 time: 0.0009s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23718154 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23718143 time: 0.0008s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23718131 time: 0.0008s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23718083 time: 0.0008s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23717999 time: 0.0008s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23717892 time: 0.0009s
# Optimization Finished!
# Total time elapsed: 8.5352s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23717892 time: 0.0010s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23717880 time: 0.0010s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23717880 time: 0.0008s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23717868 time: 0.0008s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23717856 time: 0.0008s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23717833 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23717833 time: 0.0009s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23717797 time: 0.0008s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23717773 time: 0.0008s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23717666 time: 0.0009s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23717582 time: 0.0008s
# Optimization Finished!
# Total time elapsed: 8.5277s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23717582 time: 0.0010s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23717582 time: 0.0008s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23717570 time: 0.0013s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23717570 time: 0.0008s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23717558 time: 0.0008s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23717558 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23717546 time: 0.0009s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23717511 time: 0.0009s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23717487 time: 0.0009s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23717427 time: 0.0008s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23717284 time: 0.0009s
# Optimization Finished!
# Total time elapsed: 8.8180s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23717284 time: 0.0010s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23717225 time: 0.0008s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23717201 time: 0.0008s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23717201 time: 0.0008s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23717189 time: 0.0008s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23717177 time: 0.0009s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23717165 time: 0.0010s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23717141 time: 0.0011s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23717117 time: 0.0008s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23717058 time: 0.0008s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716903 time: 0.0008s
# Optimization Finished!
# Total time elapsed: 8.5650s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716903 time: 0.0011s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716879 time: 0.0008s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716879 time: 0.0008s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716867 time: 0.0065s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716867 time: 0.0008s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716855 time: 0.0010s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716843 time: 0.0008s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716795 time: 0.0008s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716784 time: 0.0009s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716736 time: 0.0008s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716617 time: 0.0008s
# Optimization Finished!
# Total time elapsed: 8.6268s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716617 time: 0.0010s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716605 time: 0.0008s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716605 time: 0.0010s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716593 time: 0.0008s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716593 time: 0.0008s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716593 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716569 time: 0.0008s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716557 time: 0.0008s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716521 time: 0.0010s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716486 time: 0.0009s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716366 time: 0.0008s
# Optimization Finished!
# Total time elapsed: 8.5527s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716366 time: 0.0011s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716366 time: 0.0010s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716366 time: 0.0009s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716366 time: 0.0008s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716354 time: 0.0008s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716342 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716342 time: 0.0008s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716331 time: 0.0008s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716283 time: 0.0008s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716235 time: 0.0008s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716104 time: 0.0008s
# Optimization Finished!
# Total time elapsed: 8.5388s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716104 time: 0.0009s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716080 time: 0.0010s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716080 time: 0.0008s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716080 time: 0.0008s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716056 time: 0.0009s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716044 time: 0.0009s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716033 time: 0.0008s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23716021 time: 0.0008s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715985 time: 0.0009s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715949 time: 0.0010s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715866 time: 0.0008s
# Optimization Finished!
# Total time elapsed: 8.5569s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715866 time: 0.0012s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715830 time: 0.0008s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715830 time: 0.0008s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715794 time: 0.0008s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715794 time: 0.0008s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715794 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715782 time: 0.0008s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715782 time: 0.0009s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715758 time: 0.0008s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715675 time: 0.0009s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715615 time: 0.0011s
# Optimization Finished!
# Total time elapsed: 8.5434s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715615 time: 0.0010s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715568 time: 0.0009s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715568 time: 0.0008s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715568 time: 0.0009s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715544 time: 0.0008s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715532 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715520 time: 0.0008s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715520 time: 0.0008s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715472 time: 0.0008s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715460 time: 0.0008s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715353 time: 0.0008s
# Optimization Finished!
# Total time elapsed: 8.5593s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715353 time: 0.0011s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715270 time: 0.0008s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715270 time: 0.0008s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715258 time: 0.0009s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715258 time: 0.0008s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715258 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715234 time: 0.0008s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715222 time: 0.0008s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715198 time: 0.0009s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715150 time: 0.0008s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715103 time: 0.0008s
# Optimization Finished!
# Total time elapsed: 8.6003s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715103 time: 0.0016s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715103 time: 0.0009s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715103 time: 0.0008s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715103 time: 0.0012s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715103 time: 0.0008s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715103 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715091 time: 0.0009s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715079 time: 0.0008s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23715067 time: 0.0010s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23714995 time: 0.0008s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23714948 time: 0.0008s
# Optimization Finished!
# Total time elapsed: 8.6071s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23714948 time: 0.0010s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23714936 time: 0.0008s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23714936 time: 0.0008s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23714912 time: 0.0008s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23714912 time: 0.0008s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23714900 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23714888 time: 0.0009s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23714888 time: 0.0008s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23714876 time: 0.0008s
# Epoch: 9001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23714840 time: 0.0008s
# Epoch: 10001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23714721 time: 0.0008s
# Optimization Finished!
# Total time elapsed: 8.8244s
# Epoch: 0001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23714721 time: 0.0010s
# Epoch: 1001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23714697 time: 0.0009s
# Epoch: 2001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23714697 time: 0.0010s
# Epoch: 3001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23714685 time: 0.0008s
# Epoch: 4001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23714685 time: 0.0009s
# Epoch: 5001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23714662 time: 0.0008s
# Epoch: 6001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23714662 time: 0.0010s
# Epoch: 7001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23714650 time: 0.0012s
# Epoch: 8001 Train Accuracy: 0.7470 Validation Accuracy: 0.4048 Loss: 1.23714638 time: 0.0008s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/qb/17l1h3xd089d25ckc1rphr9w0000gn/T/ipykernel_90672/2388680112.py in <module>
#      15 while loss < prev_loss :
#      16     prev_loss = loss
# ---> 17     loss, op, val_op = train(adj,op.cpu().detach().numpy(),labels, random_indices, val_indices, val_op.cpu().detach().numpy())
#
# /var/folders/qb/17l1h3xd089d25ckc1rphr9w0000gn/T/ipykernel_90672/721058169.py in train(adj, features, labels, random_indices, val_indices, val_features, first)
#      68
#      69         # Calculate the gradients
# ---> 70         loss.backward(retain_graph=True)
#      71
#      72         # Update the weights
#
# ~/opt/anaconda3/envs/py39/lib/python3.9/site-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     305                 create_graph=create_graph,
#     306                 inputs=inputs)
# --> 307         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     308
#     309     def register_hook(self, hook):
#
# ~/opt/anaconda3/envs/py39/lib/python3.9/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     152         retain_graph = create_graph
#     153
# --> 154     Variable._execution_engine.run_backward(
#     155         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     156         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#
# KeyboardInterrupt:

# %%
import geopandas as gpd
from matplotlib import pyplot as plt
import matplotlib.patches as mpatches
# %matplotlib inline

# %%
# visualization

# load zip code shapefile
zips = gpd.read_file('/Users/devashishkhulbe/Desktop/teaching/Labs_and_solutions/Data/zip_code/ZIP_CODE_040114.shp')
zips['ZIPCODE'] = pd.to_numeric(zips['ZIPCODE'])
zips = zips.to_crs(epsg=4326)

# get unique zipcodes from LEHD data and merge with above shapefile
zipsAll = data.groupby(by='origin', as_index=False).sum()
zipsAll = zipsAll.merge(zips, left_on='origin', right_on='ZIPCODE')
zipsAll.drop_duplicates(subset=['origin'], inplace=True)
zipsAll.reset_index(drop=True, inplace=True)
zipsAll = gpd.GeoDataFrame(zipsAll, crs="EPSG:4326", geometry='geometry')

fig, ax = plt.subplots(nrows=1, ncols=2,figsize=(20,12))

# first plot
# borough shapefile
boro = gpd.read_file('/Users/devashishkhulbe/Desktop/research/HGNN/Borough Boundaries.zip')
boro.plot(figsize=(10,10), ax=ax[0])

colors = ['r', 'g', 'b', 'orange', 'lightgreen']

# plot boroughs
for ind, b in enumerate(boro.boro_code):
    boro[boro.boro_code == b].plot(color=colors[ind], edgecolor="black", ax=ax[0])
    
# # plot masked zips
# zipsMasked = zipsAll[zipsAll.index.isin(random_indices)][['origin', 'geometry']]

# zipsMasked.plot(facecolor='lightgrey',hatch='///', edgecolor="black", linestyle='--', ax=ax[0], label='masked zipcodes')
    
# LegendElement = [mpatches.Patch(facecolor='lightgrey', hatch='//', label='masked zipcodes')]
ax[0].axis('off')
ax[0].legend(handles = LegendElement, loc='upper left')
ax[0].set_title('borough delineations')


# second plot
# plot boroughs
boro.plot(figsize=(10,10), ax=ax[1])

colors = ['r', 'g', 'b', 'orange', 'lightgreen']
# colors = ['g', 'r', 'orange', 'lightgreen', 'b']

for ind, b in enumerate(boro.boro_code):
    boro[boro.boro_code == b].plot(color=colors[ind], edgecolor="black", ax=ax[1])
    
zipsMasked = zipsAll[zipsAll.index.isin(random_indices)][['origin', 'geometry']]

# get predictions for masked zips
pred = torch.argmax(op[0], dim=1).numpy()+1
zipsMasked['pred'] = pred[np.sort(random_indices)]

# plot masked zips
for p in zipsMasked.pred.unique():
    zipsMasked[zipsMasked.pred == p].plot(color=colors[p], edgecolor="black", linestyle='--', ax=ax[1])
    
ax[1].axis('off')
ax[1].set_title('predictions on zip code level')
# Out:
# Text(0.5, 1.0, 'predictions on zip code level')

# %% [markdown]
# ### Pytorch Basics can be found here:
#
# #### Introduction to Pytorch Tensors : https://pytorch.org/tutorials/beginner/introyt/trainingyt.html
# #### Calculating gradients using Autograd : https://pytorch.org/tutorials/beginner/introyt/autogradyt_tutorial.html
# #### Building Pytorch Models : https://pytorch.org/tutorials/beginner/introyt/modelsyt_tutorial.html
# #### Training Pytorch Models : https://pytorch.org/tutorials/beginner/introyt/trainingyt.html
